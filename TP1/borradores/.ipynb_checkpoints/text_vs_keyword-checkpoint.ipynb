# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
from fuzzywuzzy import fuzz #conda install -c conda-forge fuzzywuzzy

tweets = pd.read_csv('data/train.csv')
#vista previa de datos
tweets
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %%
tweets_text_key = tweets.loc[:,['keyword','text']]
tweets_text_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   keyword  7552 non-null   object
#  1   text     7613 non-null   object
# dtypes: object(2)
# memory usage: 119.1+ KB

# %%
tweets_text_key = tweets_text_key.dropna()
tweets_text_key.keyword.unique().tolist()
# Out:
# ['ablaze',
#  'accident',
#  'aftershock',
#  'airplane%20accident',
#  'ambulance',
#  'annihilated',
#  'annihilation',
#  'apocalypse',
#  'armageddon',
#  'army',
#  'arson',
#  'arsonist',
#  'attack',
#  'attacked',
#  'avalanche',
#  'battle',
#  'bioterror',
#  'bioterrorism',
#  'blaze',
#  'blazing',
#  'bleeding',
#  'blew%20up',
#  'blight',
#  'blizzard',
#  'blood',
#  'bloody',
#  'blown%20up',
#  'body%20bag',
#  'body%20bagging',
#  'body%20bags',
#  'bomb',
#  'bombed',
#  'bombing',
#  'bridge%20collapse',
#  'buildings%20burning',
#  'buildings%20on%20fire',
#  'burned',
#  'burning',
#  'burning%20buildings',
#  'bush%20fires',
#  'casualties',
#  'casualty',
#  'catastrophe',
#  'catastrophic',
#  'chemical%20emergency',
#  'cliff%20fall',
#  'collapse',
#  'collapsed',
#  'collide',
#  'collided',
#  'collision',
#  'crash',
#  'crashed',
#  'crush',
#  'crushed',
#  'curfew',
#  'cyclone',
#  'damage',
#  'danger',
#  'dead',
#  'death',
#  'deaths',
#  'debris',
#  'deluge',
#  'deluged',
#  'demolish',
#  'demolished',
#  'demolition',
#  'derail',
#  'derailed',
#  'derailment',
#  'desolate',
#  'desolation',
#  'destroy',
#  'destroyed',
#  'destruction',
#  'detonate',
#  'detonation',
#  'devastated',
#  'devastation',
#  'disaster',
#  'displaced',
#  'drought',
#  'drown',
#  'drowned',
#  'drowning',
#  'dust%20storm',
#  'earthquake',
#  'electrocute',
#  'electrocuted',
#  'emergency',
#  'emergency%20plan',
#  'emergency%20services',
#  'engulfed',
#  'epicentre',
#  'evacuate',
#  'evacuated',
#  'evacuation',
#  'explode',
#  'exploded',
#  'explosion',
#  'eyewitness',
#  'famine',
#  'fatal',
#  'fatalities',
#  'fatality',
#  'fear',
#  'fire',
#  'fire%20truck',
#  'first%20responders',
#  'flames',
#  'flattened',
#  'flood',
#  'flooding',
#  'floods',
#  'forest%20fire',
#  'forest%20fires',
#  'hail',
#  'hailstorm',
#  'harm',
#  'hazard',
#  'hazardous',
#  'heat%20wave',
#  'hellfire',
#  'hijack',
#  'hijacker',
#  'hijacking',
#  'hostage',
#  'hostages',
#  'hurricane',
#  'injured',
#  'injuries',
#  'injury',
#  'inundated',
#  'inundation',
#  'landslide',
#  'lava',
#  'lightning',
#  'loud%20bang',
#  'mass%20murder',
#  'mass%20murderer',
#  'massacre',
#  'mayhem',
#  'meltdown',
#  'military',
#  'mudslide',
#  'natural%20disaster',
#  'nuclear%20disaster',
#  'nuclear%20reactor',
#  'obliterate',
#  'obliterated',
#  'obliteration',
#  'oil%20spill',
#  'outbreak',
#  'pandemonium',
#  'panic',
#  'panicking',
#  'police',
#  'quarantine',
#  'quarantined',
#  'radiation%20emergency',
#  'rainstorm',
#  'razed',
#  'refugees',
#  'rescue',
#  'rescued',
#  'rescuers',
#  'riot',
#  'rioting',
#  'rubble',
#  'ruin',
#  'sandstorm',
#  'screamed',
#  'screaming',
#  'screams',
#  'seismic',
#  'sinkhole',
#  'sinking',
#  'siren',
#  'sirens',
#  'smoke',
#  'snowstorm',
#  'storm',
#  'stretcher',
#  'structural%20failure',
#  'suicide%20bomb',
#  'suicide%20bomber',
#  'suicide%20bombing',
#  'sunk',
#  'survive',
#  'survived',
#  'survivors',
#  'terrorism',
#  'terrorist',
#  'threat',
#  'thunder',
#  'thunderstorm',
#  'tornado',
#  'tragedy',
#  'trapped',
#  'trauma',
#  'traumatised',
#  'trouble',
#  'tsunami',
#  'twister',
#  'typhoon',
#  'upheaval',
#  'violent%20storm',
#  'volcano',
#  'war%20zone',
#  'weapon',
#  'weapons',
#  'whirlwind',
#  'wild%20fires',
#  'wildfire',
#  'windstorm',
#  'wounded',
#  'wounds',
#  'wreck',
#  'wreckage',
#  'wrecked']

# %% [markdown]
# # El texto de un tweet contiene la keyword?

# %%
#Recibe un string, que debe contener el substring "_concat_" una sola vez y retorna true si lo que precede al
#substring está contenido en lo que le sigue
def contain_key(s):
    x = s.split("_concat_")
    if x[0].lower() in x[1].lower():
        return True
    return False

# %% [markdown]
# Se indica si la keyword está contenida en el text

# %%
tweets_text_key['concat'] = tweets_text_key.keyword + "_concat_"+ tweets_text_key.text
tweets_text_key['text_contain_key'] = tweets_text_key.concat.transform(lambda x: contain_key(x))

# %%
rcParams['figure.figsize'] = 7,7
ax = sns.barplot(data = tweets_text_key.text_contain_key.value_counts().reset_index(),x='index',y='text_contain_key')
ax.set_title("Total de Tweets que Contienen (y que no contienen) la Keyword ")
ax.set_ylabel("Total de Tweets")
ax.set_xlabel("¿El Texto Contiene la Keyword?")
# Out:
# Text(0.5, 0, '¿El Texto Contiene la Keyword?')

# %% [markdown]
# Agrupación de keyword por similitud

# %%
#Recibe una lista de keywords y regresa un diccionario cuyas claves son los elementos de la lista pasada y los valores
#son las keywords agrupadas que las representa
def get_keyword_dic(key_list):
    key_dic = {}
    unique_list = []
    for x in key_list:
        z = x
        if "%20" in x:
            z = " ".join(x.split("%20"))
        similarity = 0
        value = ""
        for y in unique_list:
            ratio = fuzz.ratio(z,y)
            if ratio > similarity:
                similarity = ratio
                value = y
        if similarity > 75:
            key_dic[x] = value
        else:
            key_dic[x] = z
            unique_list.append(z)
    return key_dic
key_grouped = get_keyword_dic(tweets_text_key.keyword.tolist())

# %%
key_grouped
# Out:
# {'ablaze': 'ablaze',
#  'accident': 'accident',
#  'aftershock': 'aftershock',
#  'airplane%20accident': 'airplane accident',
#  'ambulance': 'ambulance',
#  'annihilated': 'annihilated',
#  'annihilation': 'annihilated',
#  'apocalypse': 'apocalypse',
#  'armageddon': 'armageddon',
#  'army': 'army',
#  'arson': 'arson',
#  'arsonist': 'arson',
#  'attack': 'attack',
#  'attacked': 'attack',
#  'avalanche': 'avalanche',
#  'battle': 'battle',
#  'bioterror': 'bioterror',
#  'bioterrorism': 'bioterror',
#  'blaze': 'ablaze',
#  'blazing': 'blazing',
#  'bleeding': 'bleeding',
#  'blew%20up': 'blew up',
#  'blight': 'blight',
#  'blizzard': 'blizzard',
#  'blood': 'blood',
#  'bloody': 'blood',
#  'blown%20up': 'blew up',
#  'body%20bag': 'body bag',
#  'body%20bagging': 'body bag',
#  'body%20bags': 'body bag',
#  'bomb': 'bomb',
#  'bombed': 'bomb',
#  'bombing': 'bombing',
#  'bridge%20collapse': 'bridge collapse',
#  'buildings%20burning': 'buildings burning',
#  'buildings%20on%20fire': 'buildings on fire',
#  'burned': 'burned',
#  'burning': 'burning',
#  'burning%20buildings': 'burning buildings',
#  'bush%20fires': 'bush fires',
#  'casualties': 'casualties',
#  'casualty': 'casualties',
#  'catastrophe': 'catastrophe',
#  'catastrophic': 'catastrophe',
#  'chemical%20emergency': 'chemical emergency',
#  'cliff%20fall': 'cliff fall',
#  'collapse': 'collapse',
#  'collapsed': 'collapse',
#  'collide': 'collide',
#  'collided': 'collide',
#  'collision': 'collision',
#  'crash': 'crash',
#  'crashed': 'crash',
#  'crush': 'crash',
#  'crushed': 'crushed',
#  'curfew': 'curfew',
#  'cyclone': 'cyclone',
#  'damage': 'damage',
#  'danger': 'danger',
#  'dead': 'dead',
#  'death': 'death',
#  'deaths': 'death',
#  'debris': 'debris',
#  'deluge': 'deluge',
#  'deluged': 'deluge',
#  'demolish': 'demolish',
#  'demolished': 'demolish',
#  'demolition': 'demolition',
#  'derail': 'derail',
#  'derailed': 'derail',
#  'derailment': 'derailment',
#  'desolate': 'desolate',
#  'desolation': 'demolition',
#  'destroy': 'destroy',
#  'destroyed': 'destroy',
#  'destruction': 'destruction',
#  'detonate': 'detonate',
#  'detonation': 'detonate',
#  'devastated': 'devastated',
#  'devastation': 'devastated',
#  'disaster': 'disaster',
#  'displaced': 'displaced',
#  'drought': 'drought',
#  'drown': 'drown',
#  'drowned': 'drown',
#  'drowning': 'drown',
#  'dust%20storm': 'dust storm',
#  'earthquake': 'earthquake',
#  'electrocute': 'electrocute',
#  'electrocuted': 'electrocute',
#  'emergency': 'emergency',
#  'emergency%20plan': 'emergency',
#  'emergency%20services': 'emergency services',
#  'engulfed': 'engulfed',
#  'epicentre': 'epicentre',
#  'evacuate': 'evacuate',
#  'evacuated': 'evacuate',
#  'evacuation': 'evacuate',
#  'explode': 'explode',
#  'exploded': 'explode',
#  'explosion': 'explosion',
#  'eyewitness': 'eyewitness',
#  'famine': 'famine',
#  'fatal': 'fatal',
#  'fatalities': 'fatalities',
#  'fatality': 'fatalities',
#  'fear': 'fear',
#  'fire': 'fire',
#  'fire%20truck': 'fire truck',
#  'first%20responders': 'first responders',
#  'flames': 'flames',
#  'flattened': 'flattened',
#  'flood': 'blood',
#  'flooding': 'flooding',
#  'floods': 'floods',
#  'forest%20fire': 'forest fire',
#  'forest%20fires': 'forest fire',
#  'hail': 'hail',
#  'hailstorm': 'hailstorm',
#  'harm': 'harm',
#  'hazard': 'hazard',
#  'hazardous': 'hazard',
#  'heat%20wave': 'heat wave',
#  'hellfire': 'hellfire',
#  'hijack': 'hijack',
#  'hijacker': 'hijack',
#  'hijacking': 'hijack',
#  'hostage': 'hostage',
#  'hostages': 'hostage',
#  'hurricane': 'hurricane',
#  'injured': 'injured',
#  'injuries': 'injured',
#  'injury': 'injured',
#  'inundated': 'inundated',
#  'inundation': 'inundation',
#  'landslide': 'landslide',
#  'lava': 'lava',
#  'lightning': 'lightning',
#  'loud%20bang': 'loud bang',
#  'mass%20murder': 'mass murder',
#  'mass%20murderer': 'mass murder',
#  'massacre': 'massacre',
#  'mayhem': 'mayhem',
#  'meltdown': 'meltdown',
#  'military': 'military',
#  'mudslide': 'mudslide',
#  'natural%20disaster': 'natural disaster',
#  'nuclear%20disaster': 'nuclear disaster',
#  'nuclear%20reactor': 'nuclear reactor',
#  'obliterate': 'obliterate',
#  'obliterated': 'obliterate',
#  'obliteration': 'obliterate',
#  'oil%20spill': 'oil spill',
#  'outbreak': 'outbreak',
#  'pandemonium': 'pandemonium',
#  'panic': 'panic',
#  'panicking': 'panicking',
#  'police': 'police',
#  'quarantine': 'quarantine',
#  'quarantined': 'quarantine',
#  'radiation%20emergency': 'radiation emergency',
#  'rainstorm': 'hailstorm',
#  'razed': 'razed',
#  'refugees': 'refugees',
#  'rescue': 'rescue',
#  'rescued': 'rescue',
#  'rescuers': 'rescue',
#  'riot': 'riot',
#  'rioting': 'rioting',
#  'rubble': 'rubble',
#  'ruin': 'ruin',
#  'sandstorm': 'sandstorm',
#  'screamed': 'screamed',
#  'screaming': 'screaming',
#  'screams': 'screamed',
#  'seismic': 'seismic',
#  'sinkhole': 'sinkhole',
#  'sinking': 'sinking',
#  'siren': 'siren',
#  'sirens': 'siren',
#  'smoke': 'smoke',
#  'snowstorm': 'sandstorm',
#  'storm': 'storm',
#  'stretcher': 'stretcher',
#  'structural%20failure': 'structural failure',
#  'suicide%20bomb': 'suicide bomb',
#  'suicide%20bomber': 'suicide bomb',
#  'suicide%20bombing': 'suicide bomb',
#  'sunk': 'sunk',
#  'survive': 'survive',
#  'survived': 'survive',
#  'survivors': 'survivors',
#  'terrorism': 'terrorism',
#  'terrorist': 'terrorism',
#  'threat': 'threat',
#  'thunder': 'thunder',
#  'thunderstorm': 'thunderstorm',
#  'tornado': 'tornado',
#  'tragedy': 'tragedy',
#  'trapped': 'trapped',
#  'trauma': 'trauma',
#  'traumatised': 'traumatised',
#  'trouble': 'rubble',
#  'tsunami': 'tsunami',
#  'twister': 'twister',
#  'typhoon': 'typhoon',
#  'upheaval': 'upheaval',
#  'violent%20storm': 'violent storm',
#  'volcano': 'volcano',
#  'war%20zone': 'war zone',
#  'weapon': 'weapon',
#  'weapons': 'weapon',
#  'whirlwind': 'whirlwind',
#  'wild%20fires': 'wild fires',
#  'wildfire': 'wild fires',
#  'windstorm': 'sandstorm',
#  'wounded': 'wounded',
#  'wounds': 'wounded',
#  'wreck': 'wreck',
#  'wreckage': 'wreck',
#  'wrecked': 'wreck'}

# %% [markdown]
# Agrupoamiento manual

# %%
key_grouped['blazing'] = 'ablaze'
key_grouped['bleeding'] = 'blood'
key_grouped['buildings%20on%20fire'] = 'buildings burning'
key_grouped['burning%20buildings'] = 'buildings burning'
key_grouped['burning'] = 'burned'
key_grouped['dead'] = 'death'
key_grouped['demolition'] = 'demolish'
key_grouped['destruction'] = 'destroy'
key_grouped['explosion'] = 'explode'
key_grouped['flood'] = 'flooding'
key_grouped['floods'] = 'flooding'
key_grouped['inundated'] = 'inundation'
key_grouped['panic'] = 'panicking'
key_grouped['rainstorm'] = 'rainstorm'
key_grouped['riot'] = 'rioting'
key_grouped['screaming'] = 'screamed'
key_grouped['snowstorm'] = 'snowstorm'
key_grouped['survivors'] = 'survive'
key_grouped['traumatised'] = 'trauma'
key_grouped['violent%20storm'] = 'storm'
key_grouped['windstorm'] = 'storm'
key_grouped['traumatised'] = 'trauma'

# %%
tweets_text_key['keyword_grouped'] = tweets_text_key.keyword.transform(lambda x: key_grouped[x])
tweets_text_key
# Out:
#       keyword                                               text  \
# 31     ablaze  @bbcmtd Wholesale Markets ablaze http://t.co/l...
# 32     ablaze  We always try to bring the heavy. #metal #RT h...
# 33     ablaze  #AFRICANBAZE: Breaking news:Nigeria flag set a...
# 34     ablaze                 Crying out for more! Set me ablaze
# 35     ablaze  On plus side LOOK AT THE SKY LAST NIGHT IT WAS...
# ...       ...                                                ...
# 7578  wrecked   @jt_ruff23 @cameronhacker and I wrecked you both
# 7579  wrecked  Three days off from work and they've pretty mu...
# 7580  wrecked  #FX #forex #trading Cramer: Iger's 3 words tha...
# 7581  wrecked  @engineshed Great atmosphere at the British Li...
# 7582  wrecked  Cramer: Iger's 3 words that wrecked Disney's s...
#
#                                                  concat  text_contain_key  \
# 31    ablaze_concat_@bbcmtd Wholesale Markets ablaze...              True
# 32    ablaze_concat_We always try to bring the heavy...             False
# 33    ablaze_concat_#AFRICANBAZE: Breaking news:Nige...              True
# 34     ablaze_concat_Crying out for more! Set me ablaze              True
# 35    ablaze_concat_On plus side LOOK AT THE SKY LAS...              True
# ...                                                 ...               ...
# 7578  wrecked_concat_@jt_ruff23 @cameronhacker and I...              True
# 7579  wrecked_concat_Three days off from work and th...              True
# 7580  wrecked_concat_#FX #forex #trading Cramer: Ige...              True
# 7581  wrecked_concat_@engineshed Great atmosphere at...              True
# 7582  wrecked_concat_Cramer: Iger's 3 words that wre...              True
#
#      keyword_grouped
# 31            ablaze
# 32            ablaze
# 33            ablaze
# 34            ablaze
# 35            ablaze
# ...              ...
# 7578           wreck
# 7579           wreck
# 7580           wreck
# 7581           wreck
# 7582           wreck
#
# [7552 rows x 5 columns]

# %%
tweets_text_key.keyword_grouped.value_counts().nlargest(20)
# Out:
# wreck                115
# evacuate             112
# explode              110
# flooding             109
# ablaze               108
# storm                108
# body bag             107
# injured              106
# blood                105
# buildings burning    105
# screamed             105
# death                104
# drown                104
# crash                104
# destroy              103
# hijack               100
# suicide bomb          99
# demolish              97
# survive               95
# rescue                92
# Name: keyword_grouped, dtype: int64
